# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('D:/Developer/Python/datasets/nyc_weather.csv')

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df['EST']
# Out:
# 0      1/1/2016
# 1      1/2/2016
# 2      1/3/2016
# 3      1/4/2016
# 4      1/5/2016
# 5      1/6/2016
# 6      1/7/2016
# 7      1/8/2016
# 8      1/9/2016
# 9     1/10/2016
# 10    1/11/2016
# 11    1/12/2016
# 12    1/13/2016
# 13    1/14/2016
# 14    1/15/2016
# 15    1/16/2016
# 16    1/17/2016
# 17    1/18/2016
# 18    1/19/2016
# 19    1/20/2016
# 20    1/21/2016
# 21    1/22/2016
# 22    1/23/2016
# 23    1/24/2016
# 24    1/25/2016
# 25    1/26/2016
# 26    1/27/2016
# 27    1/28/2016
# 28    1/29/2016
# 29    1/30/2016
# 30    1/31/2016
# Name: EST, dtype: object

# %%
df['Temperature']
# Out:
# 0     38
# 1     36
# 2     40
# 3     25
# 4     20
# 5     33
# 6     39
# 7     39
# 8     44
# 9     50
# 10    33
# 11    35
# 12    26
# 13    30
# 14    43
# 15    47
# 16    36
# 17    25
# 18    22
# 19    32
# 20    31
# 21    26
# 22    26
# 23    28
# 24    34
# 25    43
# 26    41
# 27    37
# 28    36
# 29    34
# 30    46
# Name: Temperature, dtype: int64

# %% [markdown]
# <h2>Q. What is the maximum temperature?</h2>

# %%
df['Temperature'].max()
# Out:
# 50

# %% [markdown]
# <h2>Q. On which dates did it rain?</h2>

# %%
df['EST'][df['Events'] == 'Rain']
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %% [markdown]
# <h2>Q. What is the average windspeed?</h2>

# %%
df['WindSpeedMPH'].mean()
# Out:
# 6.892857142857143

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %% [markdown]
# <h2>Filling zeros in place of NA</h2>

# %%
df.fillna(0, inplace = True)

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %% [markdown]
# <h2>Replacing 0s with NaN using numpy</h2>

# %%
df.replace(0, np.nan, inplace = True)

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df['WindSpeedMPH'].fillna(0, inplace = True)

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df['WindSpeedMPH'].mean()
# Out:
# 6.225806451612903

# %% [markdown]
# <h2>Creating a table using dictionary</h2>

# %%
weather_data = {
    'date' : ['1/1/23', '1/2/23', '1/3/23', '1/4/23', '1/5/23', '1/6/23', '1/7/23'],
    'temperature' : [32, 35, 28, 27, 33, 32, 31],
    'windspeed' : [6, 7, 2, 7, 4, 2, 5],
    'event' : ['Rain', 'Sunny', 'Snow', 'Snow', 'Rain', 'Sunny', 'Sunny']
}

# %%
weather_data
# Out:
# {'date': ['1/1/23',
#   '1/2/23',
#   '1/3/23',
#   '1/4/23',
#   '1/5/23',
#   '1/6/23',
#   '1/7/23'],
#  'temperature': [32, 35, 28, 27, 33, 32, 31],
#  'windspeed': [6, 7, 2, 7, 4, 2, 5],
#  'event': ['Rain', 'Sunny', 'Snow', 'Snow', 'Rain', 'Sunny', 'Sunny']}

# %%
df1 = pd.DataFrame(weather_data)

# %%
df1
# Out:
#      date  temperature  windspeed  event
# 0  1/1/23           32          6   Rain
# 1  1/2/23           35          7  Sunny
# 2  1/3/23           28          2   Snow
# 3  1/4/23           27          7   Snow
# 4  1/5/23           33          4   Rain
# 5  1/6/23           32          2  Sunny
# 6  1/7/23           31          5  Sunny

# %% [markdown]
# <h2>Shape of the dataframe</h2>

# %%
df.shape
# Out:
# (31, 11)

# %%
df1.shape
# Out:
# (7, 4)

# %%
rows, columns = df.shape

# %%
rows
# Out:
# 31

# %%
columns
# Out:
# 11

# %%
rows1, columns1 = df1.shape

# %%
rows1
# Out:
# 7

# %%
columns1
# Out:
# 4

# %%
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0         5.0    NaN
# 1               10           7.0               0         3.0    NaN
# 2               10           8.0               0         1.0    NaN
# 3               10           9.0               0         3.0    NaN
# 4               10           5.0               0         NaN    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df.tail()
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 26               10           7.0               T         3.0   Rain
# 27               10           5.0               0         1.0    NaN
# 28               10           8.0               0         4.0    NaN
# 29               10           7.0               0         NaN    NaN
# 30               10           5.0               0         NaN    NaN
#
#     WindDirDegrees
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
df1.head()
# Out:
#      date  temperature  windspeed  event
# 0  1/1/23           32          6   Rain
# 1  1/2/23           35          7  Sunny
# 2  1/3/23           28          2   Snow
# 3  1/4/23           27          7   Snow
# 4  1/5/23           33          4   Rain

# %%
df.head(2)
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0         5.0    NaN
# 1               10           7.0               0         3.0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275

# %%
df.tail(3)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 28               10           8.0               0         4.0    NaN
# 29               10           7.0               0         NaN    NaN
# 30               10           5.0               0         NaN    NaN
#
#     WindDirDegrees
# 28             298
# 29             257
# 30             241

# %% [markdown]
# Indexing / Slicing

# %%
df[5:15]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# 13  1/14/2016           30        12        47                 29.95
# 14  1/15/2016           43        31        62                 29.82
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 5                10           4.0               0         NaN    NaN
# ...

# %%
df[1:7]
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
# 5  1/6/2016           33         4        35                 30.50
# 6  1/7/2016           39        11        33                 30.28
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 1               10           7.0               0         3.0    NaN
# 2               10           8.0               0         1.0    NaN
# 3               10           9.0               0         3.0    NaN
# 4               10           5.0               0         NaN    NaN
# 5               10           4.0               0         NaN    NaN
# 6               10           2.0               0         3.0    NaN
#
# ...

# %%
df1[2:5]
# Out:
#      date  temperature  windspeed event
# 2  1/3/23           28          2  Snow
# 3  1/4/23           27          7  Snow
# 4  1/5/23           33          4  Rain

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['date', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.WindSpeedMPH
# Out:
# 0      8.0
# 1      7.0
# 2      8.0
# 3      9.0
# 4      5.0
# 5      4.0
# 6      2.0
# 7      4.0
# 8      8.0
# 9      0.0
# 10     0.0
# 11     6.0
# 12    10.0
# 13     5.0
# 14     5.0
# 15     7.0
# 16     6.0
# 17    12.0
# 18    11.0
# 19     6.0
# 20     6.0
# 21     0.0
# 22    16.0
# 23     6.0
# 24     3.0
# 25     7.0
# 26     7.0
# 27     5.0
# 28     8.0
# 29     7.0
# 30     5.0
# Name: WindSpeedMPH, dtype: float64

# %%
df.Events
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8         Rain
# 9         Rain
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15        Rain
# 16    Fog-Snow
# 17        Snow
# 18         NaN
# 19         NaN
# 20         NaN
# 21        Snow
# 22    Fog-Snow
# 23        Snow
# 24         NaN
# 25         NaN
# 26        Rain
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# Name: Events, dtype: object

# %%
df1.windspeed
# Out:
# 0    6
# 1    7
# 2    2
# 3    7
# 4    4
# 5    2
# 6    5
# Name: windspeed, dtype: int64

# %%
df1
# Out:
#      date  temperature  windspeed  event
# 0  1/1/23           32          6   Rain
# 1  1/2/23           35          7  Sunny
# 2  1/3/23           28          2   Snow
# 3  1/4/23           27          7   Snow
# 4  1/5/23           33          4   Rain
# 5  1/6/23           32          2  Sunny
# 6  1/7/23           31          5  Sunny

# %%
df1[['date', 'event']]
# Out:
#      date  event
# 0  1/1/23   Rain
# 1  1/2/23  Sunny
# 2  1/3/23   Snow
# 3  1/4/23   Snow
# 4  1/5/23   Rain
# 5  1/6/23  Sunny
# 6  1/7/23  Sunny

# %%
df1.temperature.max()
# Out:
# 35

# %%
df1.temperature.mean()
# Out:
# 31.142857142857142

# %%
df1.temperature.std()
# Out:
# 2.7945525240230875

# %%
df1.describe()
# Out:
#        temperature  windspeed
# count     7.000000   7.000000
# mean     31.142857   4.714286
# std       2.794553   2.138090
# min      27.000000   2.000000
# 25%      29.500000   3.000000
# 50%      32.000000   5.000000
# 75%      32.500000   6.500000
# max      35.000000   7.000000

# %%
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     31.000000   26.000000       31.000000
# mean          9.193548      6.225806    3.730769      247.129032
# std           1.939405      3.422569    2.442256       92.308086
# min           1.000000      0.000000    1.000000       34.000000
# 25%           9.000000      5.000000    2.000000      238.000000
# ...

# %%
df1[df1.temperature >= 32]
# Out:
#      date  temperature  windspeed  event
# 0  1/1/23           32          6   Rain
# 1  1/2/23           35          7  Sunny
# 4  1/5/23           33          4   Rain
# 5  1/6/23           32          2  Sunny

# %%
df1[df1.temperature == df1.temperature.max()]
# Out:
#      date  temperature  windspeed  event
# 1  1/2/23           35          7  Sunny

# %%
df1[df1.temperature == df1.temperature.min()]
# Out:
#      date  temperature  windspeed event
# 3  1/4/23           27          7  Snow

# %% [markdown]
# Printing only the date when the temperature was maximum

# %%
df1['date'][df1.temperature == df1.temperature.max()]
# Out:
# 1    1/2/23
# Name: date, dtype: object

# %%
df1[['date', 'temperature']][df1.temperature == df1.temperature.max()]
# Out:
#      date  temperature
# 1  1/2/23           35

# %%
df1
# Out:
#      date  temperature  windspeed  event
# 0  1/1/23           32          6   Rain
# 1  1/2/23           35          7  Sunny
# 2  1/3/23           28          2   Snow
# 3  1/4/23           27          7   Snow
# 4  1/5/23           33          4   Rain
# 5  1/6/23           32          2  Sunny
# 6  1/7/23           31          5  Sunny

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %% [markdown]
# <h2>Setting a different column as the index column producing a new dataframe</h2>

# %%
df1.set_index('date')
# Out:
#         temperature  windspeed  event
# date
# 1/1/23           32          6   Rain
# 1/2/23           35          7  Sunny
# 1/3/23           28          2   Snow
# 1/4/23           27          7   Snow
# 1/5/23           33          4   Rain
# 1/6/23           32          2  Sunny
# 1/7/23           31          5  Sunny

# %% [markdown]
# <h2>Setting a different column as the index column in the same dataframe</h2>

# %%
df1.set_index('date', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4136/1293917627.py in <module>
# ----> 1 df1.set_index('date', inplace = True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: "None of ['date'] are in the columns"

# %%
df1
# Out:
#         temperature  windspeed  event
# date
# 1/1/23           32          6   Rain
# 1/2/23           35          7  Sunny
# 1/3/23           28          2   Snow
# 1/4/23           27          7   Snow
# 1/5/23           33          4   Rain
# 1/6/23           32          2  Sunny
# 1/7/23           31          5  Sunny

# %%
df1.loc['1/5/23']
# Out:
# temperature      33
# windspeed         4
# event          Rain
# Name: 1/5/23, dtype: object

# %%
df1.reset_index(inplace = True)

# %%
df1
# Out:
#    index    date  temperature  windspeed  event
# 0      0  1/1/23           32          6   Rain
# 1      1  1/2/23           35          7  Sunny
# 2      2  1/3/23           28          2   Snow
# 3      3  1/4/23           27          7   Snow
# 4      4  1/5/23           33          4   Rain
# 5      5  1/6/23           32          2  Sunny
# 6      6  1/7/23           31          5  Sunny

# %%
df1.set_index('event', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4136/1444127282.py in <module>
# ----> 1 df1.set_index('event', inplace = True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# KeyError: "None of ['event'] are in the columns"

# %%
df1
# Out:
#        index    date  temperature  windspeed
# event
# Rain       0  1/1/23           32          6
# Sunny      1  1/2/23           35          7
# Snow       2  1/3/23           28          2
# Snow       3  1/4/23           27          7
# Rain       4  1/5/23           33          4
# Sunny      5  1/6/23           32          2
# Sunny      6  1/7/23           31          5

# %%
df1.loc['Rain']
# Out:
#        index    date  temperature  windspeed
# event
# Rain       0  1/1/23           32          6
# Rain       4  1/5/23           33          4

# %%
df1.reset_index(inplace = True)

# %%
df1
# Out:
#    level_0  event  index    date  temperature  windspeed
# 0        0   Rain      0  1/1/23           32          6
# 1        1  Sunny      1  1/2/23           35          7
# 2        2   Snow      2  1/3/23           28          2
# 3        3   Snow      3  1/4/23           27          7
# 4        4   Rain      4  1/5/23           33          4
# 5        5  Sunny      5  1/6/23           32          2
# 6        6  Sunny      6  1/7/23           31          5
